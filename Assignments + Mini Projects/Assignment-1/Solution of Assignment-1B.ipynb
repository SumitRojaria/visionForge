# %% [markdown]
# For this assignment we will use the iris dataset
#
# https://drive.google.com/file/d/1R7KuJPFx1ZKig90dB1xLJbpXnJs6y_Ns/view?usp=sharing
#
#
#
#
#
# **INSTRUCTIONS:**
#
# Go to File -> Save a Copy in your Drive and edit this notebook in your copy
#
# Write your code in following code cells
#
# Marks will not be given if the code is plagiarised

# %% [markdown]
# 1. Mount Google Drive

# %%
#code
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. Load the Dataset

# %%
#code
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/VisionForge/Assignments/Assignment-1/Iris_dataset.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# 3. Import the required Libraries and modules

# %%
#code
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 4. Delete a column

# %%
#code
df1 = df.drop(columns = ['SepalLengthCm'])
df1.head()
# Out:
#    Id  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1           3.5            1.4           0.2  Iris-setosa
# 1   2           3.0            1.4           0.2  Iris-setosa
# 2   3           3.2            1.3           0.2  Iris-setosa
# 3   4           3.1            1.5           0.2  Iris-setosa
# 4   5           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# 5. Display stats about data (example count, mean, std, 25%, 50%, 75%, min, max)

# %%
#code
df.describe()
# Out:
#                Id  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000    150.000000     150.000000    150.000000
# mean    75.500000      3.054000       3.758667      1.198667
# std     43.445368      0.433594       1.764420      0.763161
# min      1.000000      2.000000       1.000000      0.100000
# 25%     38.250000      2.800000       1.600000      0.300000
# 50%     75.500000      3.000000       4.350000      1.300000
# 75%    112.750000      3.300000       5.100000      1.800000
# max    150.000000      4.400000       6.900000      2.500000

# %% [markdown]
# 6. Get basic info about datatypes (example float, object)

# %%
#code
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(3), int64(1), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# 7. Display number of samples on each class

# %%
#code
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# 8. Check for NULL values

# %%
#code
df.isnull().sum()
# Out:
# Id               0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# 9. Plot histogram on Sepal Length

# %%
#code
df['SepalLengthCm'].hist()
# Out:
# <Axes: >

# %% [markdown]
# 10. Plot histogram on Petal Width

# %%
#code
df['PetalWidthCm'].hist()
# Out:
# <Axes: >

# %% [markdown]
# 11. Create list of colors and class labels

# %%
#code
colors = ['red', 'orange', 'blue']
species = ['Iris-virginica', 'Iris-versicolor', 'Iris-setosa']

# %% [markdown]
# 12. Plot Scatter plot on Sepal Width and Petal Width

# %%
#code
for i in range(3):
    # filter data on each class
    x = df[df['Species'] == species[i]]
    # plot the scatter plot
    plt.scatter(x['SepalWidthCm'], x['PetalWidthCm'], c = colors[i], label=species[i])
plt.xlabel("Sepal Width")
plt.ylabel("Petal Width")
plt.legend()

# %% [markdown]
# 13. Plot Scatter plot on Sepal Length and Petal Length

# %%
#code
for i in range(3):
    # filter data on each class
    x = df[df['Species'] == species[i]]
    # plot the scatter plot
    plt.scatter(x['SepalLengthCm'], x['PetalLengthCm'], c = colors[i], label=species[i])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.legend()

# %% [markdown]
# 14. Display Correlation Matrix

# %%
#code
df.corr()
# Out:
# <ipython-input-29-2320a11a95a0>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000
